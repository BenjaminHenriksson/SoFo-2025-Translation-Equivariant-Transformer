# %%
using Pkg
pkg"activate ."
# Out:
#   Activating new project at `c:\Users\User\Desktop\SoFo\code\SoFo-2025-Translation-Equivariant-Transformer`

# %%
pkg"dev ./TranslationalEquivariance"

pkg"add Plots, DLProteinFormats"
# Out:
#    Resolving package versions...
#     Updating `C:\Users\User\Desktop\SoFo\code\SoFo-2025-Translation-Equivariant-Transformer\Project.toml`
#   [bbb16414] + TranslationalEquivariance v0.1.0 `TranslationalEquivariance`
#     Updating `C:\Users\User\Desktop\SoFo\code\SoFo-2025-Translation-Equivariant-Transformer\Manifest.toml`
#   [79e6a3ab] + Adapt v4.3.0
#   [66dad0bd] + AliasTables v1.1.3
#   [ec485272] + ArnoldiMethod v0.4.0
#   [65a8f2f4] + ArraysOfArrays v0.6.6
#   [8ed43e74] + AssigningSecondaryStructure v0.5.1
#   [a9b6321e] + Atomix v1.1.1
#   [9ac9c2a2] + Backboner v0.12.2
#   [47718e42] + BioGenerics v0.1.5
#   [de9282ab] + BioStructures v4.6.0
#   [3c28c6f8] + BioSymbols v5.2.0
#   [c3b6d118] + BitIntegers v0.3.5
#   [d360d2e6] + ChainRulesCore v1.25.2
#   [944b1d66] + CodecZlib v0.7.8
#   [34da2185] + Compat v4.16.0
#   [187b0558] + ConstructionBase v1.6.0
#   [df93d313] + DLProteinFormats v0.1.2 `https://github.com/MurrellGroup/DLProteinFormats.jl#main`
# ...

# %%
using TranslationEquivariance
# Out:
# ArgumentError: Package TranslationEquivariance not found in current path.
#
# - Run `import Pkg; Pkg.add("TranslationEquivariance")` to install the TranslationEquivariance package.
#
#
#
# Stacktrace:
#
#   [1] macro expansion
#
#     @ .\loading.jl:2296 [inlined]
#
#   [2] macro expansion
#
#     @ .\lock.jl:273 [inlined]
#
#   [3] __require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:2271
#
#   [4] #invoke_in_world#3
#
#     @ .\essentials.jl:1089 [inlined]
#
#   [5] invoke_in_world
#
#     @ .\essentials.jl:1086 [inlined]
#
#   [6] require(into::Module, mod::Symbol)
#
#     @ Base .\loading.jl:2260
#
#   [7] eval
#
#     @ .\boot.jl:430 [inlined]
#
#   [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#
#     @ Base .\loading.jl:2734
#
#   [9] #invokelatest#2
#
#     @ .\essentials.jl:1055 [inlined]
#
#  [10] invokelatest
#
#     @ .\essentials.jl:1052 [inlined]
#
# ...
